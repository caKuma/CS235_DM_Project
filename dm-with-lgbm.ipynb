# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/linking-cleaned/classesup.npy
# /kaggle/input/linking-cleaned/classesdown.npy
# /kaggle/input/linking-cleaned/model_train_final_withencoding2.csv
# /kaggle/input/linking-cleaned/submission (2).csv
# /kaggle/input/linking-cleaned/classes.npy
# /kaggle/input/linking-cleaned/k_fold_indices_10.json
# /kaggle/input/linking-writing-processes-to-writing-quality/sample_submission.csv
# /kaggle/input/linking-writing-processes-to-writing-quality/test_logs.csv
# /kaggle/input/linking-writing-processes-to-writing-quality/train_scores.csv
# /kaggle/input/linking-writing-processes-to-writing-quality/train_logs.csv
# /kaggle/input/dm-dataset-2/classesup.npy
# /kaggle/input/dm-dataset-2/model_dataset.csv
# /kaggle/input/dm-dataset-2/k_fold_10.json
# /kaggle/input/dm-dataset-2/classesdown.npy
# /kaggle/input/dm-dataset-2/classes.npy

# %%
import json
import lightgbm as lgb
import re
import optuna
import sklearn.metrics as met
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import  StandardScaler

# Load the saved fold indices from the JSON file
with open('/kaggle/input/dm-dataset-2/k_fold_10.json', 'r') as file:
    fold_indices = json.load(file)
    
df=pd.read_csv('/kaggle/input/dm-dataset-2/model_dataset.csv')
score=df['score']
    
# Change columns names ([LightGBM] Do not support special JSON characters in feature name.)
new_names = {col: re.sub(r'[^A-Za-z0-9_]+', '', col) for col in df.columns}
new_n_list = list(new_names.values())
# [LightGBM] Feature appears more than one time.
new_names = {col: f'{new_col}_{i}' if new_col in new_n_list[:i] else new_col for i, (col, new_col) in enumerate(new_names.items())}
df = df.rename(columns=new_names)

# 'fold_indices' now contains the loaded fold indices
Y=score
X=df.drop(columns=['id','score'])
scaler = StandardScaler()
X = scaler.fit_transform(X)

# optuna hyperparameter optimization

def objective(trial,X,Y):
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2,random_state=42)
    
    param = {
            'metric':'mae' , 'random_state': 42 , 'objective':'regression', "verbosity": -1,
            'n_estimators': 10000,
            'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
            'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
            'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.6,0.7,0.8]),
        'subsample': trial.suggest_categorical('subsample', [0.6,0.7,0.8]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.05,0.01,0.01]),
        'max_depth': trial.suggest_categorical('max_depth', [10,25,50]),
        'num_leaves' : trial.suggest_int('num_leaves', 10, 20),
        'min_child_samples': trial.suggest_int('min_child_samples', 10, 20),
         'verbosity': -1
            }
    
    model=lgb.LGBMRegressor(**param) 
    early_stopping_callback = lgb.early_stopping(200, first_metric_only=True, verbose=False )
    model.fit(x_train,y_train, eval_set=[(x_test,y_test)] , callbacks=[early_stopping_callback])
    
    preds=model.predict(x_test)
    
    mae=met.mean_absolute_error(y_test,preds)
    
    return mae
    
# studying the parameter
study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial,X,Y), n_trials=50)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2023-11-07 22:37:59,867] A new study created in memory with name: no-name-84aad709-d59a-4d65-8c6b-ae8b2a63014b
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:02,907] Trial 0 finished with value: 0.5255852467430251 and parameters: {'reg_alpha': 0.0059595830294934815, 'reg_lambda': 0.2797002393021912, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 10, 'min_child_samples': 15}. Best is trial 0 with value: 0.5255852467430251.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:05,673] Trial 1 finished with value: 0.5279087616275437 and parameters: {'reg_alpha': 0.005889047709657216, 'reg_lambda': 0.4351135990442131, 'colsample_bytree': 0.7, 'subsample': 0.6, 'learning_rate': 0.01, 'max_depth': 50, 'num_leaves': 19, 'min_child_samples': 19}. Best is trial 0 with value: 0.5255852467430251.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:09,306] Trial 2 finished with value: 0.5263980438670025 and parameters: {'reg_alpha': 0.006932327614459169, 'reg_lambda': 0.4639432635828186, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'max_depth': 50, 'num_leaves': 17, 'min_child_samples': 13}. Best is trial 0 with value: 0.5255852467430251.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:12,570] Trial 3 finished with value: 0.5276853736643127 and parameters: {'reg_alpha': 0.005654797347805877, 'reg_lambda': 0.4313823364797233, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 20, 'min_child_samples': 14}. Best is trial 0 with value: 0.5255852467430251.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:13,903] Trial 4 finished with value: 0.5242879901063235 and parameters: {'reg_alpha': 0.006724388330058521, 'reg_lambda': 0.3311816083384086, 'colsample_bytree': 0.6, 'subsample': 0.7, 'learning_rate': 0.05, 'max_depth': 25, 'num_leaves': 14, 'min_child_samples': 10}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:17,157] Trial 5 finished with value: 0.5272449495639657 and parameters: {'reg_alpha': 0.005769379508363755, 'reg_lambda': 0.28408669147383186, 'colsample_bytree': 0.6, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 50, 'num_leaves': 18, 'min_child_samples': 18}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:18,596] Trial 6 finished with value: 0.5300635855060338 and parameters: {'reg_alpha': 0.006678790401245711, 'reg_lambda': 0.43837585730562667, 'colsample_bytree': 0.8, 'subsample': 0.6, 'learning_rate': 0.05, 'max_depth': 10, 'num_leaves': 17, 'min_child_samples': 20}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:21,247] Trial 7 finished with value: 0.5256819011085293 and parameters: {'reg_alpha': 0.005205754317200279, 'reg_lambda': 0.41075398030874605, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 13, 'min_child_samples': 17}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:25,717] Trial 8 finished with value: 0.5275854620557056 and parameters: {'reg_alpha': 0.006995743485457858, 'reg_lambda': 0.3830277418027575, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 18, 'min_child_samples': 19}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:27,012] Trial 9 finished with value: 0.5310434435139936 and parameters: {'reg_alpha': 0.006878326057449084, 'reg_lambda': 0.3515078238020766, 'colsample_bytree': 0.8, 'subsample': 0.6, 'learning_rate': 0.05, 'max_depth': 25, 'num_leaves': 17, 'min_child_samples': 20}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:30,390] Trial 10 finished with value: 0.5246408494942164 and parameters: {'reg_alpha': 0.006400541152235178, 'reg_lambda': 0.32245648166751795, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 14, 'min_child_samples': 10}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:34,030] Trial 11 finished with value: 0.5247168707535228 and parameters: {'reg_alpha': 0.006436669477821673, 'reg_lambda': 0.3190927576361854, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 14, 'min_child_samples': 10}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:37,120] Trial 12 finished with value: 0.5250889610134617 and parameters: {'reg_alpha': 0.006366448301171749, 'reg_lambda': 0.326453890711941, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 13, 'min_child_samples': 10}. Best is trial 4 with value: 0.5242879901063235.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:39,540] Trial 13 finished with value: 0.5241433505677237 and parameters: {'reg_alpha': 0.0063770540432759905, 'reg_lambda': 0.3102155107842023, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 11, 'min_child_samples': 12}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:41,698] Trial 14 finished with value: 0.5254588140403941 and parameters: {'reg_alpha': 0.006215714725037765, 'reg_lambda': 0.25393858209036785, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 10, 'min_child_samples': 12}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:43,859] Trial 15 finished with value: 0.52486063591573 and parameters: {'reg_alpha': 0.006674168194831531, 'reg_lambda': 0.4919226083801731, 'colsample_bytree': 0.8, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 12, 'min_child_samples': 12}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:45,912] Trial 16 finished with value: 0.5257401437569059 and parameters: {'reg_alpha': 0.006152213698145248, 'reg_lambda': 0.3572783599092289, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 11, 'min_child_samples': 12}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:49,649] Trial 17 finished with value: 0.5246981674467295 and parameters: {'reg_alpha': 0.006633942068528882, 'reg_lambda': 0.29605332415774815, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 15, 'min_child_samples': 11}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:52,948] Trial 18 finished with value: 0.5262964442568026 and parameters: {'reg_alpha': 0.006565565203915451, 'reg_lambda': 0.3593609401512788, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'max_depth': 50, 'num_leaves': 15, 'min_child_samples': 16}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:57,091] Trial 19 finished with value: 0.5257853217737711 and parameters: {'reg_alpha': 0.006172639804972057, 'reg_lambda': 0.30510831728264387, 'colsample_bytree': 0.8, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 12, 'min_child_samples': 14}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:38:59,251] Trial 20 finished with value: 0.5252008978541102 and parameters: {'reg_alpha': 0.006737291210778154, 'reg_lambda': 0.3385419785731173, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 11, 'min_child_samples': 11}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:02,769] Trial 21 finished with value: 0.5247062552575135 and parameters: {'reg_alpha': 0.006439234328626931, 'reg_lambda': 0.31880818022405777, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 14, 'min_child_samples': 10}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:06,041] Trial 22 finished with value: 0.5252640698394415 and parameters: {'reg_alpha': 0.0064372079908365945, 'reg_lambda': 0.3360393107982946, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 16, 'min_child_samples': 11}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:08,499] Trial 23 finished with value: 0.5255789243677713 and parameters: {'reg_alpha': 0.006838814793541878, 'reg_lambda': 0.30912227665997616, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 14, 'min_child_samples': 13}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:11,395] Trial 24 finished with value: 0.5256494461545059 and parameters: {'reg_alpha': 0.006292671375644816, 'reg_lambda': 0.3680337593746416, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 13, 'min_child_samples': 10}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:13,534] Trial 25 finished with value: 0.5252415695909625 and parameters: {'reg_alpha': 0.006558817319858629, 'reg_lambda': 0.34198390204454693, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 12, 'min_child_samples': 11}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:16,051] Trial 26 finished with value: 0.5260665904830981 and parameters: {'reg_alpha': 0.006785363266946858, 'reg_lambda': 0.32550952266783617, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 15, 'min_child_samples': 13}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:17,979] Trial 27 finished with value: 0.5259324090201086 and parameters: {'reg_alpha': 0.006506477012314864, 'reg_lambda': 0.37725918177812223, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 11, 'min_child_samples': 12}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:22,433] Trial 28 finished with value: 0.5254032629277066 and parameters: {'reg_alpha': 0.0063130391434734374, 'reg_lambda': 0.29196244162356716, 'colsample_bytree': 0.8, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 50, 'num_leaves': 16, 'min_child_samples': 10}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:25,270] Trial 29 finished with value: 0.5255364755172444 and parameters: {'reg_alpha': 0.006047222610768745, 'reg_lambda': 0.2689316800577957, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 13, 'min_child_samples': 15}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:29,067] Trial 30 finished with value: 0.5262656526370789 and parameters: {'reg_alpha': 0.00673926560295887, 'reg_lambda': 0.3048729688895451, 'colsample_bytree': 0.6, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 10, 'min_child_samples': 14}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:32,574] Trial 31 finished with value: 0.5250081864786416 and parameters: {'reg_alpha': 0.006620201942610343, 'reg_lambda': 0.2919453587825161, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 15, 'min_child_samples': 11}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:35,971] Trial 32 finished with value: 0.5245212225603665 and parameters: {'reg_alpha': 0.006574910825295469, 'reg_lambda': 0.30263954827259604, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 16, 'min_child_samples': 11}. Best is trial 13 with value: 0.5241433505677237.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:39,358] Trial 33 finished with value: 0.5235872324843371 and parameters: {'reg_alpha': 0.00696289257129596, 'reg_lambda': 0.3111656149412144, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 16, 'min_child_samples': 11}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:42,057] Trial 34 finished with value: 0.5267493975360399 and parameters: {'reg_alpha': 0.006940816491572929, 'reg_lambda': 0.2777989592526553, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 16, 'min_child_samples': 13}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:44,985] Trial 35 finished with value: 0.5268233061363496 and parameters: {'reg_alpha': 0.006998178437861121, 'reg_lambda': 0.3085849498386953, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 50, 'num_leaves': 18, 'min_child_samples': 12}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:48,080] Trial 36 finished with value: 0.5261105069917361 and parameters: {'reg_alpha': 0.006852956750370069, 'reg_lambda': 0.2778999748983189, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 20, 'min_child_samples': 11}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:51,029] Trial 37 finished with value: 0.5265752203693708 and parameters: {'reg_alpha': 0.006786064959699219, 'reg_lambda': 0.2987245577424732, 'colsample_bytree': 0.7, 'subsample': 0.6, 'learning_rate': 0.01, 'max_depth': 50, 'num_leaves': 19, 'min_child_samples': 12}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:54,545] Trial 38 finished with value: 0.5269571948264832 and parameters: {'reg_alpha': 0.0065576418139024475, 'reg_lambda': 0.31328331066929305, 'colsample_bytree': 0.6, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 16, 'min_child_samples': 14}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:39:57,635] Trial 39 finished with value: 0.5266846734792446 and parameters: {'reg_alpha': 0.006692447550452842, 'reg_lambda': 0.3309696529517254, 'colsample_bytree': 0.6, 'subsample': 0.6, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 19, 'min_child_samples': 13}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:01,713] Trial 40 finished with value: 0.5257024670349871 and parameters: {'reg_alpha': 0.006905354826451634, 'reg_lambda': 0.33943169514442156, 'colsample_bytree': 0.8, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 17, 'min_child_samples': 17}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:02,985] Trial 41 finished with value: 0.5248015784522391 and parameters: {'reg_alpha': 0.006353550761279906, 'reg_lambda': 0.31770523861496264, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.05, 'max_depth': 25, 'num_leaves': 14, 'min_child_samples': 10}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:05,970] Trial 42 finished with value: 0.5258891684060472 and parameters: {'reg_alpha': 0.006526894825181059, 'reg_lambda': 0.31996394915957443, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 16, 'min_child_samples': 11}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:09,851] Trial 43 finished with value: 0.5256821370420182 and parameters: {'reg_alpha': 0.005922841598770392, 'reg_lambda': 0.3279074032305856, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 15, 'min_child_samples': 10}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:13,239] Trial 44 finished with value: 0.524648440415693 and parameters: {'reg_alpha': 0.006651752243673416, 'reg_lambda': 0.3051894189468658, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 17, 'min_child_samples': 11}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:16,974] Trial 45 finished with value: 0.525227434201987 and parameters: {'reg_alpha': 0.006851864132582006, 'reg_lambda': 0.28595261433373254, 'colsample_bytree': 0.7, 'subsample': 0.6, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 14, 'min_child_samples': 10}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:20,804] Trial 46 finished with value: 0.523903961733806 and parameters: {'reg_alpha': 0.006440542588586782, 'reg_lambda': 0.345592366461464, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 17, 'min_child_samples': 10}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:23,710] Trial 47 finished with value: 0.5252056758992607 and parameters: {'reg_alpha': 0.006759198691299911, 'reg_lambda': 0.3442928107069215, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 17, 'min_child_samples': 12}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:26,603] Trial 48 finished with value: 0.526531850957097 and parameters: {'reg_alpha': 0.006261633222806764, 'reg_lambda': 0.35107696355469725, 'colsample_bytree': 0.6, 'subsample': 0.8, 'learning_rate': 0.01, 'max_depth': 50, 'num_leaves': 18, 'min_child_samples': 11}. Best is trial 33 with value: 0.5235872324843371.
# /tmp/ipykernel_32/550066612.py:37: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_alpha': trial.suggest_loguniform('reg_alpha',0.005,0.007),
# /tmp/ipykernel_32/550066612.py:38: FutureWarning: suggest_loguniform has been deprecated in v3.0.0. This feature will be removed in v6.0.0. See https://github.com/optuna/optuna/releases/tag/v3.0.0. Use suggest_float(..., log=True) instead.
#   'reg_lambda': trial.suggest_loguniform('reg_lambda',0.25, 0.5 ),
# [I 2023-11-07 22:40:31,242] Trial 49 finished with value: 0.5258956568893676 and parameters: {'reg_alpha': 0.006998611635505161, 'reg_lambda': 0.33306758973106326, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 10, 'num_leaves': 17, 'min_child_samples': 10}. Best is trial 33 with value: 0.5235872324843371.
# Number of finished trials: 50
# Best trial: {'reg_alpha': 0.00696289257129596, 'reg_lambda': 0.3111656149412144, 'colsample_bytree': 0.7, 'subsample': 0.7, 'learning_rate': 0.01, 'max_depth': 25, 'num_leaves': 16, 'min_child_samples': 11}

# %%
params
# Out:
# {'reg_alpha': 0.00696289257129596,
#  'reg_lambda': 0.3111656149412144,
#  'colsample_bytree': 0.7,
#  'subsample': 0.7,
#  'learning_rate': 0.01,
#  'max_depth': 25,
#  'num_leaves': 16,
#  'min_child_samples': 11}

# %%
params=study.best_params 
params['random_state'] = 42
params['n_estimators'] = 10000 
params['metric'] = 'mae'
params['objective']='regression'
mae=[]
# You can access the train and test indices for each fold as needed
for fold_number, fold_data in enumerate(fold_indices):
    train_index = fold_data['train_indices']
    test_index = fold_data['test_indices']
    X_train, X_test = X[train_index], X[test_index]
    y_train, y_test = Y[train_index], Y[test_index]
    model = lgb.LGBMRegressor(objective='regression',metric='mae',  n_estimators =12000)
    early_stopping_callback = lgb.early_stopping(200, first_metric_only=True, verbose=False )
    verbose_callback = lgb.log_evaluation(100)
    model.fit(X_train,y_train, eval_set=[(X_test,y_test)] , callbacks=[early_stopping_callback, verbose_callback])
    
    mae.append(met.mean_absolute_error(y_test,model.predict(X_test)))
    print(f'Mean absolute error is fold is {mae[-1]}')
# Out:
# [100]	valid_0's l1: 0.544975
# [200]	valid_0's l1: 0.551734
# Mean absolute error is fold is 0.5413048550488309
# [100]	valid_0's l1: 0.537137
# [200]	valid_0's l1: 0.536744
# Mean absolute error is fold is 0.5154181073518406
# [100]	valid_0's l1: 0.502714
# [200]	valid_0's l1: 0.511754
# Mean absolute error is fold is 0.5016119538496592
# [100]	valid_0's l1: 0.557064
# [200]	valid_0's l1: 0.55882
# Mean absolute error is fold is 0.5410043606952623
# [100]	valid_0's l1: 0.495809
# [200]	valid_0's l1: 0.50976
# Mean absolute error is fold is 0.48268266003908733
# [100]	valid_0's l1: 0.465566
# [200]	valid_0's l1: 0.464359
# [300]	valid_0's l1: 0.467902
# [400]	valid_0's l1: 0.467656
# Mean absolute error is fold is 0.4635156591273206
# [100]	valid_0's l1: 0.512295
# [200]	valid_0's l1: 0.516994
# Mean absolute error is fold is 0.49889080531414665
# [100]	valid_0's l1: 0.499173
# [200]	valid_0's l1: 0.50708
# Mean absolute error is fold is 0.4963818971555343
# [100]	valid_0's l1: 0.479044
# [200]	valid_0's l1: 0.486332
# Mean absolute error is fold is 0.47529841606609663
# [100]	valid_0's l1: 0.520505
# [200]	valid_0's l1: 0.530682
# Mean absolute error is fold is 0.48923160691558537

# %%
Final_mae=np.mean(mae)
Final_mae
# Out:
# 0.5005340321563364

# %% [markdown]
# # Hence, the final MAE is 0.500
